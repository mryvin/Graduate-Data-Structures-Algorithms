# %%
from random import shuffle, randint
import sys

def arrange(jars, lids):
    if len(jars) != len(lids):
        raise ValueError("Number of jars and lids must be the same")

    # Merge sort function that compares across arrays
    def merge_sort(arr):
        if len(arr) > 1:
            mid = len(arr) // 2
            left_half = arr[:mid]
            right_half = arr[mid:]

            # Recursively sort the left and right halves
            merge_sort(left_half)
            merge_sort(right_half)

            i = j = k = 0

            # Merge the sorted halves back into the original array
            while i < len(left_half) and j < len(right_half):
                if compare_jar_to_lid(left_half[i], right_half[j]):
                    arr[k] = left_half[i]
                    i += 1
                else:
                    arr[k] = right_half[j]
                    j += 1
                k += 1

            # Copy any remaining elements from the left and right halves
            while i < len(left_half):
                arr[k] = left_half[i]
                i += 1
                k += 1

            while j < len(right_half):
                arr[k] = right_half[j]
                j += 1
                k += 1

    # Comparator function for comparing jars to lids
    def compare_jar_to_lid(jar, lid):
        return jar < lid

    # Apply the merge sort to both jars and lids
    merge_sort(jars)
    merge_sort(lids)

jars = list({randint(0, sys.maxsize) for i in range(15)})
lids = list(jars)

shuffle(jars)
shuffle(lids)

print(lids)
print(jars)

arrange(jars, lids)

print(jars == lids)

print(lids)
print(jars)
# Out:
# [2251516365261646996, 8625786384612888656, 695487368642142028, 4789947867304183764, 627576797175960130, 8550002783602452853, 6960208849358865231, 1185884764652868057, 888153466273461878, 4053146594587889763, 8036107551189493625, 6958483233977856831, 8923933609960779039, 306846024096241213, 4673326413198250848]
# [6958483233977856831, 8036107551189493625, 4053146594587889763, 8923933609960779039, 2251516365261646996, 1185884764652868057, 306846024096241213, 888153466273461878, 4673326413198250848, 4789947867304183764, 6960208849358865231, 627576797175960130, 695487368642142028, 8550002783602452853, 8625786384612888656]
# True
# [306846024096241213, 627576797175960130, 695487368642142028, 888153466273461878, 1185884764652868057, 2251516365261646996, 4053146594587889763, 4673326413198250848, 4789947867304183764, 6958483233977856831, 6960208849358865231, 8036107551189493625, 8550002783602452853, 8625786384612888656, 8923933609960779039]
# [306846024096241213, 627576797175960130, 695487368642142028, 888153466273461878, 1185884764652868057, 2251516365261646996, 4053146594587889763, 4673326413198250848, 4789947867304183764, 6958483233977856831, 6960208849358865231, 8036107551189493625, 8550002783602452853, 8625786384612888656, 8923933609960779039]

# %%
def heapify(arr, n, i):
    largest = i  # Initialize largest as the root
    left = 2 * i + 1  # Left child
    right = 2 * i + 2  # Right child

    # Check if left child exists and is greater than the root
    if left < n and arr[left] > arr[largest]:
        largest = left

    # Check if right child exists and is greater than the root
    if right < n and arr[right] > arr[largest]:
        largest = right

    # Swap the root if needed
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        print(arr)  # Print the array after swapping
        heapify(arr, n, largest)

def heap_sort(arr):
    n = len(arr)

    # Build a max heap
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)

    # Extract elements from the heap one by one
    for i in range(n - 1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]
        print(arr)  # Print the array after extracting the maximum element
        heapify(arr, i, 0)

# Example usage:
input_array = ["lifo", "fifo", "data", "type", "hash", "heap", "sort", "link", "list", "push", "find", "root", "leaf", "tree", "null", "path", "node", "left", "less", "exch", "sink", "swim", "next", "swap"]
print("Initial Array:", input_array)
heap_sort(input_array)
print("Sorted Array:", input_array)
# Out:
# Initial Array: ['lifo', 'fifo', 'data', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# ['lifo', 'fifo', 'data', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'find', 'swap', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'root']
# ['lifo', 'fifo', 'data', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'swim', 'swap', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'find', 'next', 'root']
# ['lifo', 'fifo', 'data', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'sink', 'swim', 'swap', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'push', 'find', 'next', 'root']
# ['lifo', 'fifo', 'data', 'type', 'hash', 'heap', 'sort', 'path', 'list', 'sink', 'swim', 'swap', 'leaf', 'tree', 'null', 'link', 'node', 'left', 'less', 'exch', 'push', 'find', 'next', 'root']
# ['lifo', 'fifo', 'data', 'type', 'hash', 'heap', 'tree', 'path', 'list', 'sink', 'swim', 'swap', 'leaf', 'sort', 'null', 'link', 'node', 'left', 'less', 'exch', 'push', 'find', 'next', 'root']
# ['lifo', 'fifo', 'data', 'type', 'hash', 'swap', 'tree', 'path', 'list', 'sink', 'swim', 'heap', 'leaf', 'sort', 'null', 'link', 'node', 'left', 'less', 'exch', 'push', 'find', 'next', 'root']
# ['lifo', 'fifo', 'data', 'type', 'hash', 'swap', 'tree', 'path', 'list', 'sink', 'swim', 'root', 'leaf', 'sort', 'null', 'link', 'node', 'left', 'less', 'exch', 'push', 'find', 'next', 'heap']
# ['lifo', 'fifo', 'data', 'type', 'swim', 'swap', 'tree', 'path', 'list', 'sink', 'hash', 'root', 'leaf', 'sort', 'null', 'link', 'node', 'left', 'less', 'exch', 'push', 'find', 'next', 'heap']
# ['lifo', 'fifo', 'data', 'type', 'swim', 'swap', 'tree', 'path', 'list', 'sink', 'next', 'root', 'leaf', 'sort', 'null', 'link', 'node', 'left', 'less', 'exch', 'push', 'find', 'hash', 'heap']
# ['lifo', 'fifo', 'tree', 'type', 'swim', 'swap', 'data', 'path', 'list', 'sink', 'next', 'root', 'leaf', 'sort', 'null', 'link', 'node', 'left', 'less', 'exch', 'push', 'find', 'hash', 'heap']
# ['lifo', 'fifo', 'tree', 'type', 'swim', 'swap', 'sort', 'path', 'list', 'sink', 'next', 'root', 'leaf', 'data', 'null', 'link', 'node', 'left', 'less', 'exch', 'push', 'find', 'hash', 'heap']
# ['lifo', 'type', 'tree', 'fifo', 'swim', 'swap', 'sort', 'path', 'list', 'sink', 'next', 'root', 'leaf', 'data', 'null', 'link', 'node', 'left', 'less', 'exch', 'push', 'find', 'hash', 'heap']
# ['lifo', 'type', 'tree', 'path', 'swim', 'swap', 'sort', 'fifo', 'list', 'sink', 'next', 'root', 'leaf', 'data', 'null', 'link', 'node', 'left', 'less', 'exch', 'push', 'find', 'hash', 'heap']
# ['lifo', 'type', 'tree', 'path', 'swim', 'swap', 'sort', 'node', 'list', 'sink', 'next', 'root', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'push', 'find', 'hash', 'heap']
# ['type', 'lifo', 'tree', 'path', 'swim', 'swap', 'sort', 'node', 'list', 'sink', 'next', 'root', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'push', 'find', 'hash', 'heap']
# ['type', 'swim', 'tree', 'path', 'lifo', 'swap', 'sort', 'node', 'list', 'sink', 'next', 'root', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'push', 'find', 'hash', 'heap']
# ['type', 'swim', 'tree', 'path', 'sink', 'swap', 'sort', 'node', 'list', 'lifo', 'next', 'root', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'push', 'find', 'hash', 'heap']
# ['type', 'swim', 'tree', 'path', 'sink', 'swap', 'sort', 'node', 'list', 'push', 'next', 'root', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'lifo', 'find', 'hash', 'heap']
# ['heap', 'swim', 'tree', 'path', 'sink', 'swap', 'sort', 'node', 'list', 'push', 'next', 'root', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'lifo', 'find', 'hash', 'type']
# ['tree', 'swim', 'heap', 'path', 'sink', 'swap', 'sort', 'node', 'list', 'push', 'next', 'root', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'lifo', 'find', 'hash', 'type']
# ['tree', 'swim', 'swap', 'path', 'sink', 'heap', 'sort', 'node', 'list', 'push', 'next', 'root', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'lifo', 'find', 'hash', 'type']
# ['tree', 'swim', 'swap', 'path', 'sink', 'root', 'sort', 'node', 'list', 'push', 'next', 'heap', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'lifo', 'find', 'hash', 'type']
# ['hash', 'swim', 'swap', 'path', 'sink', 'root', 'sort', 'node', 'list', 'push', 'next', 'heap', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'lifo', 'find', 'tree', 'type']
# ['swim', 'hash', 'swap', 'path', 'sink', 'root', 'sort', 'node', 'list', 'push', 'next', 'heap', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'lifo', 'find', 'tree', 'type']
# ['swim', 'sink', 'swap', 'path', 'hash', 'root', 'sort', 'node', 'list', 'push', 'next', 'heap', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'lifo', 'find', 'tree', 'type']
# ['swim', 'sink', 'swap', 'path', 'push', 'root', 'sort', 'node', 'list', 'hash', 'next', 'heap', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'lifo', 'find', 'tree', 'type']
# ['swim', 'sink', 'swap', 'path', 'push', 'root', 'sort', 'node', 'list', 'lifo', 'next', 'heap', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'hash', 'find', 'tree', 'type']
# ['find', 'sink', 'swap', 'path', 'push', 'root', 'sort', 'node', 'list', 'lifo', 'next', 'heap', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'hash', 'swim', 'tree', 'type']
# ['swap', 'sink', 'find', 'path', 'push', 'root', 'sort', 'node', 'list', 'lifo', 'next', 'heap', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'hash', 'swim', 'tree', 'type']
# ['swap', 'sink', 'sort', 'path', 'push', 'root', 'find', 'node', 'list', 'lifo', 'next', 'heap', 'leaf', 'data', 'null', 'link', 'fifo', 'left', 'less', 'exch', 'hash', 'swim', 'tree', 'type']
# ['swap', 'sink', 'sort', 'path', 'push', 'root', 'null', 'node', 'list', 'lifo', 'next', 'heap', 'leaf', 'data', 'find', 'link', 'fifo', 'left', 'less', 'exch', 'hash', 'swim', 'tree', 'type']
# ['hash', 'sink', 'sort', 'path', 'push', 'root', 'null', 'node', 'list', 'lifo', 'next', 'heap', 'leaf', 'data', 'find', 'link', 'fifo', 'left', 'less', 'exch', 'swap', 'swim', 'tree', 'type']
# ['sort', 'sink', 'hash', 'path', 'push', 'root', 'null', 'node', 'list', 'lifo', 'next', 'heap', 'leaf', 'data', 'find', 'link', 'fifo', 'left', 'less', 'exch', 'swap', 'swim', 'tree', 'type']
# ['sort', 'sink', 'root', 'path', 'push', 'hash', 'null', 'node', 'list', 'lifo', 'next', 'heap', 'leaf', 'data', 'find', 'link', 'fifo', 'left', 'less', 'exch', 'swap', 'swim', 'tree', 'type']
# ['sort', 'sink', 'root', 'path', 'push', 'leaf', 'null', 'node', 'list', 'lifo', 'next', 'heap', 'hash', 'data', 'find', 'link', 'fifo', 'left', 'less', 'exch', 'swap', 'swim', 'tree', 'type']
# ['exch', 'sink', 'root', 'path', 'push', 'leaf', 'null', 'node', 'list', 'lifo', 'next', 'heap', 'hash', 'data', 'find', 'link', 'fifo', 'left', 'less', 'sort', 'swap', 'swim', 'tree', 'type']
# ['sink', 'exch', 'root', 'path', 'push', 'leaf', 'null', 'node', 'list', 'lifo', 'next', 'heap', 'hash', 'data', 'find', 'link', 'fifo', 'left', 'less', 'sort', 'swap', 'swim', 'tree', 'type']
# ['sink', 'push', 'root', 'path', 'exch', 'leaf', 'null', 'node', 'list', 'lifo', 'next', 'heap', 'hash', 'data', 'find', 'link', 'fifo', 'left', 'less', 'sort', 'swap', 'swim', 'tree', 'type']
# ['sink', 'push', 'root', 'path', 'next', 'leaf', 'null', 'node', 'list', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'link', 'fifo', 'left', 'less', 'sort', 'swap', 'swim', 'tree', 'type']
# ['less', 'push', 'root', 'path', 'next', 'leaf', 'null', 'node', 'list', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'link', 'fifo', 'left', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['root', 'push', 'less', 'path', 'next', 'leaf', 'null', 'node', 'list', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'link', 'fifo', 'left', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['root', 'push', 'null', 'path', 'next', 'leaf', 'less', 'node', 'list', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'link', 'fifo', 'left', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['left', 'push', 'null', 'path', 'next', 'leaf', 'less', 'node', 'list', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'link', 'fifo', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['push', 'left', 'null', 'path', 'next', 'leaf', 'less', 'node', 'list', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'link', 'fifo', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['push', 'path', 'null', 'left', 'next', 'leaf', 'less', 'node', 'list', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'link', 'fifo', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['push', 'path', 'null', 'node', 'next', 'leaf', 'less', 'left', 'list', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'link', 'fifo', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['push', 'path', 'null', 'node', 'next', 'leaf', 'less', 'link', 'list', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'left', 'fifo', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['fifo', 'path', 'null', 'node', 'next', 'leaf', 'less', 'link', 'list', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'left', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['path', 'fifo', 'null', 'node', 'next', 'leaf', 'less', 'link', 'list', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'left', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['path', 'node', 'null', 'fifo', 'next', 'leaf', 'less', 'link', 'list', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'left', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['path', 'node', 'null', 'list', 'next', 'leaf', 'less', 'link', 'fifo', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'left', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['left', 'node', 'null', 'list', 'next', 'leaf', 'less', 'link', 'fifo', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['null', 'node', 'left', 'list', 'next', 'leaf', 'less', 'link', 'fifo', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['null', 'node', 'less', 'list', 'next', 'leaf', 'left', 'link', 'fifo', 'lifo', 'exch', 'heap', 'hash', 'data', 'find', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['find', 'node', 'less', 'list', 'next', 'leaf', 'left', 'link', 'fifo', 'lifo', 'exch', 'heap', 'hash', 'data', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['node', 'find', 'less', 'list', 'next', 'leaf', 'left', 'link', 'fifo', 'lifo', 'exch', 'heap', 'hash', 'data', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['node', 'next', 'less', 'list', 'find', 'leaf', 'left', 'link', 'fifo', 'lifo', 'exch', 'heap', 'hash', 'data', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['node', 'next', 'less', 'list', 'lifo', 'leaf', 'left', 'link', 'fifo', 'find', 'exch', 'heap', 'hash', 'data', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['data', 'next', 'less', 'list', 'lifo', 'leaf', 'left', 'link', 'fifo', 'find', 'exch', 'heap', 'hash', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['next', 'data', 'less', 'list', 'lifo', 'leaf', 'left', 'link', 'fifo', 'find', 'exch', 'heap', 'hash', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['next', 'list', 'less', 'data', 'lifo', 'leaf', 'left', 'link', 'fifo', 'find', 'exch', 'heap', 'hash', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['next', 'list', 'less', 'link', 'lifo', 'leaf', 'left', 'data', 'fifo', 'find', 'exch', 'heap', 'hash', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['hash', 'list', 'less', 'link', 'lifo', 'leaf', 'left', 'data', 'fifo', 'find', 'exch', 'heap', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['list', 'hash', 'less', 'link', 'lifo', 'leaf', 'left', 'data', 'fifo', 'find', 'exch', 'heap', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['list', 'link', 'less', 'hash', 'lifo', 'leaf', 'left', 'data', 'fifo', 'find', 'exch', 'heap', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['heap', 'link', 'less', 'hash', 'lifo', 'leaf', 'left', 'data', 'fifo', 'find', 'exch', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['link', 'heap', 'less', 'hash', 'lifo', 'leaf', 'left', 'data', 'fifo', 'find', 'exch', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['link', 'lifo', 'less', 'hash', 'heap', 'leaf', 'left', 'data', 'fifo', 'find', 'exch', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['exch', 'lifo', 'less', 'hash', 'heap', 'leaf', 'left', 'data', 'fifo', 'find', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['lifo', 'exch', 'less', 'hash', 'heap', 'leaf', 'left', 'data', 'fifo', 'find', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['lifo', 'heap', 'less', 'hash', 'exch', 'leaf', 'left', 'data', 'fifo', 'find', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['lifo', 'heap', 'less', 'hash', 'find', 'leaf', 'left', 'data', 'fifo', 'exch', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['exch', 'heap', 'less', 'hash', 'find', 'leaf', 'left', 'data', 'fifo', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['less', 'heap', 'exch', 'hash', 'find', 'leaf', 'left', 'data', 'fifo', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['less', 'heap', 'left', 'hash', 'find', 'leaf', 'exch', 'data', 'fifo', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['fifo', 'heap', 'left', 'hash', 'find', 'leaf', 'exch', 'data', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['left', 'heap', 'fifo', 'hash', 'find', 'leaf', 'exch', 'data', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['left', 'heap', 'leaf', 'hash', 'find', 'fifo', 'exch', 'data', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['data', 'heap', 'leaf', 'hash', 'find', 'fifo', 'exch', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['leaf', 'heap', 'data', 'hash', 'find', 'fifo', 'exch', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['leaf', 'heap', 'fifo', 'hash', 'find', 'data', 'exch', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['exch', 'heap', 'fifo', 'hash', 'find', 'data', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['heap', 'exch', 'fifo', 'hash', 'find', 'data', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['heap', 'hash', 'fifo', 'exch', 'find', 'data', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['data', 'hash', 'fifo', 'exch', 'find', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['hash', 'data', 'fifo', 'exch', 'find', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['hash', 'find', 'fifo', 'exch', 'data', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['data', 'find', 'fifo', 'exch', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['find', 'data', 'fifo', 'exch', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['find', 'exch', 'fifo', 'data', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['fifo', 'exch', 'data', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['exch', 'data', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# Sorted Array: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']

# %%
def quicksort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    result = quicksort(left) + middle + quicksort(right)
    print(result)  # Print the entire array after each step
    return result

# Example usage
array_to_sort = ["lifo", "fifo", "data", "type", "hash", "heap", "sort", "link", "list", "push", "find", "root", "leaf", "tree", "null", "path", "node", "left", "less", "exch", "sink", "swim", "next", "swap"]

print("Initial array:", array_to_sort)
sorted_array = quicksort(array_to_sort.copy())  # Pass a copy to avoid modifying the original array
print("Sorted array:", sorted_array)
# Out:
# Initial array: ['lifo', 'fifo', 'data', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# ['exch', 'fifo']
# ['data', 'exch', 'fifo']
# ['data', 'exch', 'fifo', 'find']
# ['data', 'exch', 'fifo', 'find', 'hash']
# ['data', 'exch', 'fifo', 'find', 'hash', 'heap']
# ['less', 'lifo']
# ['less', 'lifo', 'link']
# ['less', 'lifo', 'link', 'list', 'next']
# ['left', 'less', 'lifo', 'link', 'list', 'next']
# ['left', 'less', 'lifo', 'link', 'list', 'next', 'node']
# ['push', 'root']
# ['sort', 'swap']
# ['sort', 'swap', 'swim']
# ['push', 'root', 'sink', 'sort', 'swap', 'swim']
# ['path', 'push', 'root', 'sink', 'sort', 'swap', 'swim']
# ['path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# Sorted array: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']

# %%
def selection_sort(arr):
    n = len(arr)

    for i in range(n):
        min_index = i

        # Find the index of the minimum element in the unsorted part
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j

        # Swap the found minimum element with the first unsorted element
        arr[i], arr[min_index] = arr[min_index], arr[i]

        # Print the current state of the array after each step
        print(f"Step {i + 1}: {arr}")

# Example array
array_to_sort = ['lifo', 'fifo', 'data', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']

# Print the initial array
print("Initial array:", array_to_sort)

# Perform selection sort and print each step
selection_sort(array_to_sort)
# Out:
# Initial array: ['lifo', 'fifo', 'data', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 1: ['data', 'fifo', 'lifo', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 2: ['data', 'exch', 'lifo', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'fifo', 'sink', 'swim', 'next', 'swap']
# Step 3: ['data', 'exch', 'fifo', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'lifo', 'sink', 'swim', 'next', 'swap']
# Step 4: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'type', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'lifo', 'sink', 'swim', 'next', 'swap']
# Step 5: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'type', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'lifo', 'sink', 'swim', 'next', 'swap']
# Step 6: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'type', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'lifo', 'sink', 'swim', 'next', 'swap']
# Step 7: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'link', 'list', 'push', 'type', 'root', 'sort', 'tree', 'null', 'path', 'node', 'left', 'less', 'lifo', 'sink', 'swim', 'next', 'swap']
# Step 8: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'list', 'push', 'type', 'root', 'sort', 'tree', 'null', 'path', 'node', 'link', 'less', 'lifo', 'sink', 'swim', 'next', 'swap']
# Step 9: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'push', 'type', 'root', 'sort', 'tree', 'null', 'path', 'node', 'link', 'list', 'lifo', 'sink', 'swim', 'next', 'swap']
# Step 10: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'type', 'root', 'sort', 'tree', 'null', 'path', 'node', 'link', 'list', 'push', 'sink', 'swim', 'next', 'swap']
# Step 11: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'root', 'sort', 'tree', 'null', 'path', 'node', 'type', 'list', 'push', 'sink', 'swim', 'next', 'swap']
# Step 12: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'sort', 'tree', 'null', 'path', 'node', 'type', 'root', 'push', 'sink', 'swim', 'next', 'swap']
# Step 13: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'tree', 'null', 'path', 'node', 'type', 'root', 'push', 'sink', 'swim', 'sort', 'swap']
# Step 14: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'tree', 'type', 'root', 'push', 'sink', 'swim', 'sort', 'swap']
# Step 15: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'tree', 'type', 'root', 'push', 'sink', 'swim', 'sort', 'swap']
# Step 16: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'tree', 'type', 'root', 'push', 'sink', 'swim', 'sort', 'swap']
# Step 17: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'type', 'root', 'tree', 'sink', 'swim', 'sort', 'swap']
# Step 18: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'type', 'tree', 'sink', 'swim', 'sort', 'swap']
# Step 19: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'tree', 'type', 'swim', 'sort', 'swap']
# Step 20: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'type', 'swim', 'tree', 'swap']
# Step 21: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# Step 22: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# Step 23: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
# Step 24: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1

        # Move elements of arr[0..i-1] that are greater than key to one position ahead of their current position
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1

        # Insert the key into its correct position
        arr[j + 1] = key

        # Print the current state of the array after each step
        print(f"Step {i}: {arr}")

# Example array
array_to_sort = ['lifo', 'fifo', 'data', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']

# Print the initial array
print("Initial array:", array_to_sort)

# Perform insertion sort and print each step
insertion_sort(array_to_sort)
# Out:
# Initial array: ['lifo', 'fifo', 'data', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 1: ['fifo', 'lifo', 'data', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 2: ['data', 'fifo', 'lifo', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 3: ['data', 'fifo', 'lifo', 'type', 'hash', 'heap', 'sort', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 4: ['data', 'fifo', 'hash', 'lifo', 'type', 'heap', 'sort', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 5: ['data', 'fifo', 'hash', 'heap', 'lifo', 'type', 'sort', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 6: ['data', 'fifo', 'hash', 'heap', 'lifo', 'sort', 'type', 'link', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 7: ['data', 'fifo', 'hash', 'heap', 'lifo', 'link', 'sort', 'type', 'list', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 8: ['data', 'fifo', 'hash', 'heap', 'lifo', 'link', 'list', 'sort', 'type', 'push', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 9: ['data', 'fifo', 'hash', 'heap', 'lifo', 'link', 'list', 'push', 'sort', 'type', 'find', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 10: ['data', 'fifo', 'find', 'hash', 'heap', 'lifo', 'link', 'list', 'push', 'sort', 'type', 'root', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 11: ['data', 'fifo', 'find', 'hash', 'heap', 'lifo', 'link', 'list', 'push', 'root', 'sort', 'type', 'leaf', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 12: ['data', 'fifo', 'find', 'hash', 'heap', 'leaf', 'lifo', 'link', 'list', 'push', 'root', 'sort', 'type', 'tree', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 13: ['data', 'fifo', 'find', 'hash', 'heap', 'leaf', 'lifo', 'link', 'list', 'push', 'root', 'sort', 'tree', 'type', 'null', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 14: ['data', 'fifo', 'find', 'hash', 'heap', 'leaf', 'lifo', 'link', 'list', 'null', 'push', 'root', 'sort', 'tree', 'type', 'path', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 15: ['data', 'fifo', 'find', 'hash', 'heap', 'leaf', 'lifo', 'link', 'list', 'null', 'path', 'push', 'root', 'sort', 'tree', 'type', 'node', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 16: ['data', 'fifo', 'find', 'hash', 'heap', 'leaf', 'lifo', 'link', 'list', 'node', 'null', 'path', 'push', 'root', 'sort', 'tree', 'type', 'left', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 17: ['data', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'lifo', 'link', 'list', 'node', 'null', 'path', 'push', 'root', 'sort', 'tree', 'type', 'less', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 18: ['data', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'node', 'null', 'path', 'push', 'root', 'sort', 'tree', 'type', 'exch', 'sink', 'swim', 'next', 'swap']
# Step 19: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'node', 'null', 'path', 'push', 'root', 'sort', 'tree', 'type', 'sink', 'swim', 'next', 'swap']
# Step 20: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'tree', 'type', 'swim', 'next', 'swap']
# Step 21: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swim', 'tree', 'type', 'next', 'swap']
# Step 22: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swim', 'tree', 'type', 'swap']
# Step 23: ['data', 'exch', 'fifo', 'find', 'hash', 'heap', 'leaf', 'left', 'less', 'lifo', 'link', 'list', 'next', 'node', 'null', 'path', 'push', 'root', 'sink', 'sort', 'swap', 'swim', 'tree', 'type']
